# %% [markdown]
# ## Evaluating multi-group promps

# %%
import pandas as pd
import numpy as np
from labelrepo.projects.participant_demographics import get_participant_demographics
from labelrepo.database import get_database_connection

subgroups = get_participant_demographics(include_locations=True)
docs_info = pd.read_sql(
    "select pmcid, publication_year, title, text from document",
    get_database_connection(),

)

# %%
# Load multi group as well
jerome_pd = subgroups[(subgroups.project_name == 'participant_demographics') & \
                      (subgroups.annotator_name == 'Jerome_Dockes')]

counts = jerome_pd.groupby('pmcid').count().reset_index()
multi_group_pmcids = counts[counts['count'] > 1].pmcid
multi_group = jerome_pd[jerome_pd.pmcid.isin(multi_group_pmcids)]

# Get multi group docs
multi_group_docs = docs_info[docs_info.pmcid.isin(multi_group.pmcid)]

# %% [markdown]
# ## Embed documents

# %%
import openai
openai.api_key = open('/home/zorro/.keys/open_ai.key').read().strip()

# %%
from embed import embed_pmc_articles, query_embeddings
texts = multi_group_docs[['pmcid', 'text']].to_dict(orient='records')
# embeddings = embed_pmc_articles(texts)
import pickle
# pickle.dump(embeddings, open('data/multi_group_embeddings.pkl', 'wb'))
embeddings = pickle.load(open('data/multi_group_embeddings.pkl', 'rb'))

# %%
embeddings = pd.DataFrame(embeddings)

# %% [markdown]
# ## Extract group demographics across all docs

# %%
# from extract import extract_from_match
# sections, predictions = extract_on_match(embeddings, multi_group, **ZERO_SHOT_MULTI_GROUP, num_workers=3)
# pickle.dump(predictions, open('data/full_text_gpt4_multi_group.pkl', 'wb'))
predictions = pickle.load(open('data/full_text_gpt4_multi_group.pkl', 'rb'))

# %%
# Clean up predictions

def _clean_predictions(predictions):
    # Clean known issues with GPT predictions

    predicitons = predictions.copy()
    
    predictions = predictions.fillna(value=np.nan)
    predictions['group_name'] = predictions['group_name'].fillna('healthy')

    # If group name is healthy, blank out diagnosis
    predictions.loc[predictions.group_name == 'healthy', 'diagnosis'] = np.nan
    predictions = predictions.replace(0.0, np.nan)

    # Drop rows where count is NA
    predictions = predictions[~pd.isna(predictions['count'])]

    # Set group_name to healthy if no diagnosis

    predictions.loc[(predictions['group_name'] != 'healthy') & (pd.isna(predictions['diagnosis'])), 'group_name'] = 'healthy'

    return predictions

# %%
clean_preds = _clean_predictions(predictions)

# %% [markdown]
# # Evaluation

# %%
# Subset annotation df to only include studies with body annotations
subset_cols = ['count', 'diagnosis', 'group_name', 'subgroup_name', 'male count',
       'female count', 'age mean', 'age minimum', 'age maximum',
       'age median', 'pmcid']
sub_multi_group = multi_group[multi_group.pmcid.isin(predictions.pmcid)][subset_cols].sort_values('pmcid')

# %%
from evaluate import evaluate_predictions

# %%
ix_corr_n_groups, ix_more_groups, ix_less_groups = evaluate_predictions(predictions, sub_multi_group)
# Out:
# Exact match # of groups: 0.86
#  More groups predicted: 0.09
#  Less groups predicted: 0.06
#
# {'age maximum': 0.63,
#  'age mean': 0.75,
#  'age median': 0.77,
#  'age minimum': 0.63,
#  'count': 0.8,
#  'diagnosis': 0.08,
#  'female count': 0.65,
#  'group_name': 0.65,
#  'male count': 0.62,
#  'subgroup_name': 0.03}

# %%
# With "cleaned up" predictions

_ = evaluate_predictions(clean_preds, sub_multi_group)
# Out:
# Exact match # of groups: 0.88
#  More groups predicted: 0.06
#  Less groups predicted: 0.06
#
# {'age maximum': 0.71,
#  'age mean': 0.74,
#  'age median': 0.85,
#  'age minimum': 0.71,
#  'count': 0.8,
#  'diagnosis': 0.52,
#  'female count': 0.75,
#  'group_name': 0.79,
#  'male count': 0.67,
#  'subgroup_name': 0.03}

# %% [markdown]
# ### Try on single group

# %%
single_group_embeddings = pickle.load(open('data/single_group_embeddings.pkl', 'rb'))
single_group_embeddings = pd.DataFrame(single_group_embeddings)

single_group_pmcids = counts[counts['count'] == 1].pmcid
single_group = jerome_pd[jerome_pd.pmcid.isin(single_group_pmcids)]

# %%
single_sections, single_preds = extract_on_match(single_group_embeddings, single_group, **ZERO_SHOT_MULTI_GROUP, num_workers=3)
# Out:
# 100%|███████████████████████████████████████████| 69/69 [00:47<00:00,  1.46it/s]

# %%
sub_single_group = single_group[single_group.pmcid.isin(single_preds.pmcid)][subset_cols].sort_values('pmcid')

# %%
# pickle.dump(single_preds, open('data/full_text_gpt4_single_group_2.pkl', 'wb'))

# %%
clean_single_preds = _clean_predictions(single_preds)

# %%
ix_corr_n_groups_single, ix_more_groups_single, _= evaluate_predictions(single_preds, sub_single_group)
# Out:
# Exact match # of groups: 0.86
#  More groups predicted: 0.14
#  Less groups predicted: 0.00
#
# {'age maximum': 0.78,
#  'age mean': 0.72,
#  'age median': 0.81,
#  'age minimum': 0.78,
#  'count': 0.74,
#  'diagnosis': 0.06,
#  'female count': 0.59,
#  'group_name': 0.51,
#  'male count': 0.64,
#  'subgroup_name': 0.0}

# %%
# With "cleaned up" predictions
_= evaluate_predictions(clean_single_preds, sub_single_group)
# Out:
# Exact match # of groups: 0.88
#  More groups predicted: 0.12
#  Less groups predicted: 0.00
#
# {'age maximum': 0.83,
#  'age mean': 0.72,
#  'age median': 0.87,
#  'age minimum': 0.83,
#  'count': 0.74,
#  'diagnosis': 0.68,
#  'female count': 0.64,
#  'group_name': 0.78,
#  'male count': 0.67,
#  'subgroup_name': 0.0}

# %% [markdown]
# ### Error types:
#
# - Many times multiple rows get created for a single group study, each time a new "revised" sample size is mention (i.e. after exclusion)
# - 2x the human annotation had less detai (i.e. total N instead sub group chars, that were combined into 1 group)

# %% [markdown]
# ### Compare labels predicted vs given, on subset w/ matching group numbers

# %%
# Subset to only look at studies w/ same # of groups
subset_pred_corrgroups = predictions[predictions.pmcid.isin(ix_corr_n_groups)]
subset_annot_corrgroups = sub_multi_group[sub_multi_group.pmcid.isin(ix_corr_n_groups)]

# %%
annot_diag = subset_annot_corrgroups[(subset_annot_corrgroups.group_name == 'patients')][['count', 'pmcid', 'diagnosis']]
pred_diag = subset_pred_corrgroups[subset_pred_corrgroups.group_name == 'patients'][['count', 'pmcid', 'diagnosis']]
pd.merge(annot_diag, pred_diag, on=['pmcid', 'count'])
# Out:
#     count    pmcid                                   diagnosis_x  \
# 0      15  2648877                      Autism Spectrum Disorder
# 1      10  3742334                         chronic marijuana use
# 2      17  3877773                             Tourette syndrome
# 3      16  3984441                     dementia with Lewy bodies
# 4      30  4190683      Attention Deficit Hyperactivity Disorder
# 5      18  4265725                    Autism spectrum conditions
# 6      32  4473263                chronic left-hemisphere stroke
# 7      11  4589842                                    Depression
# 8      42  5394595        bronchial asthma without acute attacks
# 9      34  5413198                            Alcohol dependence
# 10     58  5598991                  early adult onset depression
# 11     62  5598991                  later adult onset depression
# 12     25  5761874                        temporal lobe epilepsy
# 13     21  6024199                 posttraumatic stress disorder
# 14     21  6024199                 posttraumatic stress disorder
# 15     21  6246657                              bipolar disorder
# 16     40  6246657                     major depressive disorder
# 17     17  6382839                                panic disorder
# 18     18  6412974                   Juvenile myoclonic epilepsy
# 19     10  6585311               chronic post-stroke hemiparesis
# 20    151  6611425                                 schizophrenia
# 21     17  6902076                     Dementia with Lewy bodies
# 22     43  7118554                     major depressive disorder
# 23     26  7194032                      Autism spectrum disorder
# 24     18  7275001                                   lung cancer
# 25     54  7416060                        Chronic cannabis users
# 26     24  7485713                       multiple system atrophy
# 27    255  7721229                      autism spectrum disorder
# 28    151  7721229                                 schizophrenia
# 29     53  7829678                      Type 2 diabetes mellitus
# 30      6  7838677                     mild Alzheimer's dementia
# 31     19  7875881                     major depressive disorder
# 32     32  8172304                             chronic urticaria
# 33     28  8213933                      autism spectrum disorder
# 34     18  8544331  neovascular age-related macular degeneration
# 35     31  8550949                                 schizophrenia
# 36     20  8883821                      autism spectrum disorder
# 37     28  8883821                                 schizophrenia
# 38     66  8933317                        Temporal lobe epilepsy
# 39     24  8939409                            internet addiction
# 40    151  9057100                                 schizophrenia
# 41    100  9435010                                 schizophrenia
#
#                                           diagnosis_y
# 0                            Autism Spectrum Disorder
# 1                        chronic marijuana (MJ) users
# 2                                                  TS
# 3                                                 DLB
# 4                                                ADHD
# 5                                                 ASC
# 6                      chronic left-hemisphere stroke
# 7                                  depressed patients
# 8                                    bronchial asthma
# 9                                                 ADP
# 10                                                EOD
# 11                                                LOD
# 12                             temporal lobe epilepsy
# 13                                               PTSD
# 14                             trauma-exposed control
# 15                                                BDD
# 16                                                MDD
# 17                                                 PD
# 18                                       JME patients
# 19                    chronic post-stroke hemiparesis
# 20                                                 SZ
# 21                                                DLB
# 22                                                MDD
# 23                                                ASD
# 24                               lung cancer patients
# 25                                     cannabis users
# 26                                         MSA c-type
# 27                                                ASD
# 28                                                 SZ
# 29                                               T2DM
# 30                                                mAD
# 31                                                MDD
# 32                                  chronic urticaria
# 33                                                ASD
# 34                                               nAMD
# 35       drug-nave/free first episode psychosis (FEP)
# 36                           autism spectrum disorder
# 37                                      schizophrenia
# 38  TLE patients with unilateral hippocampal scler...
# 39                                                 IA
# 40                                                 SZ
# 41                                                FES

# %%
annot_diag = subset_annot_corrgroups[(subset_annot_corrgroups.group_name == 'healthy')][['count', 'pmcid', 'diagnosis']]
pred_diag = subset_pred_corrgroups[subset_pred_corrgroups.group_name == 'healthy'][['count', 'pmcid', 'diagnosis']]
pd.merge(annot_diag, pred_diag, on=['pmcid', 'count'])
# Out:
#     count    pmcid diagnosis_x                        diagnosis_y
# 0      19  2561002         NaN                                NaN
# 1      15  2561002         NaN                                NaN
# 2      18  2648877         NaN               non-autistic control
# 3      24  3502502         NaN                            healthy
# 4      44  3511796         NaN                            healthy
# 5      18  3742334         NaN  nonusing (NU) comparison subjects
# 6      15  3877773         NaN                                 HC
# 7      17  3984441         NaN                           controls
# 8      11  4589842         NaN                 healthy volunteers
# 9      35  5292583         NaN                                NaN
# 10     60  5394595         NaN                                HCs
# 11     26  5413198         NaN                                 HC
# 12     60  5598991         NaN
# 13     52  5598991         NaN
# 14     23  5761874         NaN                            healthy
# 15     17  5902547         NaN                                NaN
# 16     41  5902547         NaN                                NaN
# 17     44  5902547         NaN                                NaN
# 18     70  6246657         NaN                                NaN
# 19     17  6382839         NaN                                 HC
# 20    163  6611425         NaN                            healthy
# 21     20  6902076         NaN                                NaN
# 22     56  7118554         NaN                                NaN
# 23     28  7194032         NaN               typically-developing
# 24     32  7272423         NaN                            control
# 25     21  7275001         NaN                   healthy controls
# 26     90  7416060         NaN                           controls
# 27    160  7721229         NaN                            healthy
# 28    314  7721229         NaN                                 HC
# 29     39  7829678         NaN                                NaN
# 30     17  7875881         NaN                                 HC
# 31     40  8172304         NaN                            healthy
# 32     27  8213933         NaN                                 TD
# 33     18  8544331         NaN                                NaN
# 34     35  8550949         NaN
# 35     30  8883821         NaN              neurotypical controls
# 36     31  8933317         NaN              healthy controls (HC)
# 37     23  8939409         NaN                                 HC
# 38    163  9057100         NaN                                HCs
# 39     50  9435010         NaN                                NaN

# %% [markdown]
# ### Other groups

# %%
subset_pred_corrgroups[subset_pred_corrgroups.group_name.isin(['healthy', 'patients']) == False][['count', 'pmcid', 'diagnosis', 'group_name']]
# Out:
#      count    pmcid                             diagnosis  \
# 12    23.0  8933759                        healthy adults
# 48    20.0  7485713                                   NaN
# 53    20.0  6820536                          fibromyalgia
# 54    20.0  6820536                                   NaN
# 62    24.0  3965851                                   NaN
# 63    18.0  3965851                                   NaN
# 81   260.0  3991323                                   NaN
# 82    28.0  3991323                                   NaN
# 83   164.0  4174863                                   NaN
# 84    46.0  4174863                                   NaN
# 87    51.0  6664004                                adults
# 88    53.0  6664004                           adolescents
# 89    51.0  6664004                                   NaN
# 95     4.0  6016936                                   NaN
# 97    18.0  4265725                                    TD
# 106   19.0  3660406                                   NaN
# 107   15.0  3660406                                   NaN
# 118   12.0  2995581  normal or corrected-to-normal vision
# 119   18.0  2995581                                 naive
# 124   18.0  4473263                               healthy
# 137   32.0  8018944                               healthy
# 138    9.0  8018944                               healthy
# 144   30.0  4190683                               healthy
#
#                    group_name
# 12                   controls
# 48                   controls
# 53                         FM
# 54                         HC
# 62               participants
# 63               participants
# 81                 adolescent
# 82                      adult
# 83               incarcerated
# 84           non-incarcerated
# 87       Study 1 (Behavioral)
# 88       Study 1 (Behavioral)
# 89             Study 2 (fMRI)
# 95   Supplementary Experiment
# 97                   controls
# 106                   younger
# 107                     older
# 118                  subjects
# 119                  subjects
# 124                volunteers
# 137                volunteers
# 138                volunteers
# 144                   control

# %% [markdown]
# ### Error types
# - Will often fail to set name to `healthy` for controls.
#    - Can probably come up with a whitelist of terms that can be translated to `healthy`:
#       - ['control', 'volunteers', 'subjects', 'participants', 'adults'] + if diagnosis == `n/a`

# %% [markdown]
# ## Look at example of failures

# %% [markdown]
# ### When model predicted more groups

# %%
sub_multi_group[sub_multi_group.pmcid.isin(ix_more_groups)].sort_values('pmcid')
# Out:
#      count                  diagnosis group_name     subgroup_name  \
# 130     16   autism spectrum disorder   patients                 _
# 131     16                        NaN    healthy                 _
# 136     19  unipolar major depression   patients  validation study
# 135     20  unipolar major depression   patients     primary study
# 138     19                        NaN    healthy  validation study
# 137     19                        NaN    healthy     primary study
# 90      15                        NaN    healthy                 _
# 89      72            ischemic stroke   patients                 _
# 20      39                        NaN    healthy               tsd
# 21      15                        NaN    healthy           control
# 225     38                        NaN    healthy              APOE
# 224     38                        NaN    healthy                NC
# 44      20                        NaN    healthy                 _
# 43      20                  offenders   patients                 _
#
#      male count  female count  age mean  age minimum  age maximum  age median  \
# 130        16.0           NaN       NaN          8.0         18.0         NaN
# 131         NaN           NaN       NaN          NaN          NaN         NaN
# 136         NaN           NaN       NaN         18.0         65.0         NaN
# 135         NaN           NaN       NaN         18.0         65.0         NaN
# 138         NaN           NaN       NaN         18.0         65.0         NaN
# 137         NaN           NaN       NaN         18.0         65.0         NaN
# 90          NaN           NaN       NaN         60.0         70.0         NaN
# 89          NaN           NaN       NaN         60.0         70.0         NaN
# 20         22.0          17.0      33.5          NaN          NaN         NaN
# 21          7.0           8.0      34.5          NaN          NaN         NaN
# 225        16.0          22.0       NaN          NaN          NaN         NaN
# 224        16.0          22.0       NaN          NaN          NaN         NaN
# 44         20.0           NaN       NaN          NaN          NaN         NaN
# 43         20.0           NaN       NaN          NaN          NaN         NaN
#
#        pmcid
# 130  5279905
# 131  5279905
# 136  5416685
# 135  5416685
# 138  5416685
# 137  5416685
# 90   5665859
# 89   5665859
# 20   7260173
# 21   7260173
# 225  9205431
# 224  9205431
# 44   9230060
# 43   9230060

# %%
predictions[predictions.pmcid.isin(ix_more_groups)].sort_values('pmcid')
# Out:
#      count                  diagnosis       group_name      subgroup_name  \
# 132   16.0                         TD          healthy
# 131   16.0                        ASD         patients
# 130   30.0                    healthy          healthy           children
# 129   20.0                        ASD         patients           children
# 22    20.0                        NaN          healthy  validation sample
# 18     NaN
# 19    20.0  unipolar major depression         patients      primary study
# 20    19.0  unipolar major depression         patients   validation study
# 21    19.0                        NaN          healthy     primary sample
# 74    15.0           healthy subjects          healthy
# 73    72.0            stroke patients         patients
# 71   133.0            ischemic stroke         patients
# 72    15.0                        NaN          healthy      blank control
# 152   70.0                    healthy          healthy             adults
# 154   16.0                        NaN          control             adults
# 153   54.0                        NaN     experimental             adults
# 15     NaN                        NaN      noncarriers                NaN
# 14    38.0                        NaN  APOE-4 carriers                NaN
# 13    76.0                        NaN          healthy                NaN
# 8     20.0                        NaN          healthy           controls
# 7      7.0          non-violent crime        offenders                 NV
# 6      7.0         predatory violence        offenders                 VP
# 5      6.0         affective violence        offenders                 VA
#
#      male count  female count  age mean   age range  age minimum  age maximum  \
# 132        16.0           NaN       NaN         NaN          NaN          NaN
# 131        16.0           NaN      13.0        8-18          8.0         18.0
# 130        15.0          15.0       9.0        6-13          6.0         13.0
# 129        10.0          10.0       8.0        5-12          5.0         12.0
# 22          NaN           NaN       NaN         NaN          NaN          NaN
# 18          NaN           NaN       NaN                      NaN          NaN
# 19          NaN           NaN       NaN         NaN          NaN          NaN
# 20          NaN           NaN       NaN         NaN          NaN          NaN
# 21          NaN           NaN       NaN         NaN          NaN          NaN
# 74          NaN           NaN       NaN                      NaN          NaN
# 73          NaN           NaN       NaN                      NaN          NaN
# 71          NaN           NaN       NaN         NaN          NaN          NaN
# 72          NaN           NaN       NaN         NaN          NaN          NaN
# 152        41.0           NaN       NaN  2150 years          NaN          NaN
# 154         7.0           NaN      34.5  2150 years          NaN          NaN
# 153        28.0           NaN      33.5  2150 years          NaN          NaN
# 15          NaN           NaN       NaN         NaN          NaN          NaN
# 14          NaN          22.0       NaN         NaN          NaN          NaN
# 13         60.0           NaN      49.9       40-60         40.0         60.0
# 8          20.0           NaN       NaN         NaN          NaN          NaN
# 7           7.0           NaN       NaN         NaN          NaN          NaN
# 6           7.0           NaN       NaN         NaN          NaN          NaN
# 5           6.0           NaN       NaN         NaN          NaN          NaN
#
#      age median    pmcid
# 132         NaN  5279905
# 131        13.0  5279905
# 130         9.0  5279905
# 129         8.0  5279905
# 22          NaN  5416685
# 18          NaN  5416685
# 19          NaN  5416685
# 20          NaN  5416685
# 21          NaN  5416685
# 74          NaN  5665859
# 73          NaN  5665859
# 71          NaN  5665859
# 72          NaN  5665859
# 152         NaN  7260173
# 154         NaN  7260173
# 153         NaN  7260173
# 15          NaN  9205431
# 14          NaN  9205431
# 13         49.9  9205431
# 8           NaN  9230060
# 7           NaN  9230060
# 6           NaN  9230060
# 5           NaN  9230060

# %%
sections[sections.pmcid == 9230060].iloc[0].content
# Out:
# '\n## 2. Materials and Methods \n  \nThis prospective study was approved by the local institutional review board of Kaohsiung Veterans General Hospital (protocol number: VGHKS93-CT2-09). This study enrolled 20 right-handed male offenders who were further separated into 3 sub-groups by their records of court verdict: six offenders had committed affective violence (VA group), seven offenders had committed predatory violence (VP group), and seven had committed non-violent crime (NV group). The VA offenders were defined as the subjects who impulsively or affectively committed violent crime. The VP offenders were defined as the subjects who purposely planned to commit violent crime with detailed documentation in the court records. The NV offenders were defined as the subjects who committed non-violent crime based on the documents in court record. In addition, 20 age-matched right-handed male non-criminal healthy controls (HC group) were enrolled for comparisons. All subjects underwent psychological assessments as well as magnetic resonance imaging (MRI) scans of the brain after providing their written informed consent. Individuals with metal implants, claustrophobia, neurological disorders, or any space-occupying lesion in the brain MRI were excluded from this study. \n'

# %% [markdown]
# ### Error types
# - Sometimes there is repeated information (for example, in Methods and Results). Not clear which section to "trust". In addition there are confusions about total N.
# - It seems to create a group if given the introduction, but it oftne lacks count. Which means we can probably drop those observations
# - Final N and exclusion criteria always seems to confuse the models. In the case of multigroup prompt, instead of choosing one, it often will invent another group -- how to handle conflicting information?
# - Also: it OFTEN, invents group_names other than `patients` or `healthy`. I think we can assume that if `diagnosis == NaN` or `healthy` then group_name can be corrected to `healthy`, and if there is a diagnosis then group_name should be patient. However, there will be rare times when something meaning healthy is given to diagnosis, and group name is something like 'control'.
#
#
# Ideas for finding correction section:
# - If can find "Methods" in body--- use that and search within that, or sections that follow.
# - Also, should save subsection prior to splitting up-- save all headers to be able to select methods section
# - If not, then search over entire document.
# - Iterate until some information is generated, and iterate if there's no hits

# %% [markdown]
# ### When model predicted fewer groups

# %%
sub_multi_group[sub_multi_group.pmcid.isin(ix_less_groups)].sort_values('pmcid')
# Out:
#      count                                 diagnosis group_name  \
# 57      20                                       NaN    healthy
# 58      19                                       NaN    healthy
# 205     19                                       NaN    healthy
# 206     19                                       NaN    healthy
# 101     88  attention/deficit hyperactivity disorder   patients
# 102     79                                       NaN    healthy
# 163    573                                       NaN    healthy
# 164    593                                       NaN    healthy
# 161    539                  autism spectrum disorder   patients
# 162    521                  autism spectrum disorder   patients
#
#              subgroup_name  male count  female count  age mean  age minimum  \
# 57               dataset 1         NaN           NaN       NaN          NaN
# 58               dataset 2         NaN           NaN       NaN          NaN
# 205     work with children         9.0          10.0       NaN          NaN
# 206  no work with children         9.0          10.0       NaN          NaN
# 101                      _         NaN           NaN       NaN          NaN
# 102                      _         NaN           NaN       NaN          NaN
# 163                abide 1         NaN           NaN       NaN          NaN
# 164                abide 2         NaN           NaN       NaN          NaN
# 161                abide 1         NaN           NaN       NaN          NaN
# 162                abide 2         NaN           NaN       NaN          NaN
#
#      age maximum  age median    pmcid
# 57           NaN         NaN  4352055
# 58           NaN         NaN  4352055
# 205          NaN         NaN  7395771
# 206          NaN         NaN  7395771
# 101          NaN         NaN  8782893
# 102          NaN         NaN  8782893
# 163          NaN         NaN  9407088
# 164          NaN         NaN  9407088
# 161          NaN         NaN  9407088
# 162          NaN         NaN  9407088

# %%
predictions[predictions.pmcid.isin(ix_less_groups)].sort_values('pmcid')
# Out:
#      count        diagnosis                group_name    subgroup_name  \
# 122   20.0              NaN              participants              NaN
# 64    38.0          healthy                    adults        childless
# 9    167.0             ADHD  children and adolescents
# 3    539.0     ASD patients                  patients     ASD patients
# 4    573.0  normal controls                   healthy  normal controls
#
#      male count  female count  age mean age range  age minimum  age maximum  \
# 122         NaN           NaN       NaN       NaN          NaN          NaN
# 64         19.0          19.0     24.08      3.33         19.0         29.0
# 9           NaN           NaN       NaN       NaN          NaN          NaN
# 3         300.0         239.0     25.00     18-40         18.0         40.0
# 4         300.0         273.0     28.00     20-45         20.0         45.0
#
#      age median    pmcid
# 122         NaN  4352055
# 64         24.0  7395771
# 9           NaN  8782893
# 3          26.0  9407088
# 4          29.0  9407088

# %%
sections[sections.pmcid == 9407088].iloc[0].content
# Out:
# '\n## 3. Experiments \n  \n### 3.1. Data \n  \nThe data used in this article come from the Autism Brain Imaging Data Exchange (ABIDE) project [ ]. This project aims to accelerate the understanding of the deep brain mechanism of autism spectrum disorder (ASD), which integrates the brain structure and functional imaging data from many laboratories around the world. The abide I and abide II datasets were used. The abide I data were collected from 17 centers, including 1112 subjects, including 539 ASD patients and 573 normal controls; the abide II dataset was collected from 19 centers, including 1114 subjects, including 521 ASD patients and 593 normal controls. \n\nTo construct a 3D custom fMRI template using fMRI time-series data, we first need to preprocess the data. The basic idea of fMRI data preprocessing is to eliminate the timing error of the interlayer scanning and the head movement error caused by the subject’s head movement in the scanning process, and then carry out the time-layer correction and head movement correction for the fMRI functional image. Because the custom template constructed for the subjects is eager to retain the individual specificity of the subjects, it does not need to be standardized. Therefore, the steps of the MRI structural image and the fMRI functional image registration and applying the corresponding MRI registration parameters to the fMRI functional images after the timing and head movement correction do not need to be introduced in the preprocessing process, and the data do not need to be smoothed. Therefore, this chapter only uses the time-horizon correction and head movement correction to process the data. \n\nThe SPM12 plug-in in the MATLAB 2020A environment is used for the data preprocessing in this experiment. The fMRI sequence registration algorithm based on the feature point extraction and the template construction algorithm based on image fusion can be applied to the template construction task of various single-subject medical image sequences. The relevant experimental environment is shown in  . \n\n'

# %% [markdown]
# ### Error types
# - Combining two groups into 1 (not necessarily wrong)-- happened 2x, usually combining control group w/ patient group
# - Missed a dataset (abide)
#
# Overall, not much we can do about this
