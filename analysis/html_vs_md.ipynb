# %% [markdown]
# # Compare HTML to MD extraction

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
results = pd.read_csv('../outputs/full_results.csv')

# %%
results
# Out:
#          variable  hungarian_matched_error  counts  avg_mean_percentage_error  \
# 0           count                     0.16    1.00                       0.08
# 1       diagnosis                     0.80     NaN                        NaN
# 2      group_name                     0.18     NaN                        NaN
# 3   subgroup_name                     0.97     NaN                        NaN
# 4      male_count                     0.40    0.97                       0.07
# 5    female_count                     0.41    0.96                       0.06
# 6        age_mean                     0.42    0.97                       0.00
# 7     age_minimum                     0.50    0.93                       0.01
# 8     age_maximum                     0.50    0.95                       0.02
# 9      age_median                     0.63     NaN                        NaN
# 10          count                     0.13    1.00                       0.09
# ...

# %%
### Revise this to compare exactly the same articles
