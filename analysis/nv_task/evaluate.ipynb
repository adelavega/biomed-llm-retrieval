# %%
import json
import pandas as pd

# %% [markdown]
# #### Load GPT Extracted Data

# %%
with open('../../outputs/nv_task/extractions/full_lb_nv_task-zeroshot_gpt-4o-mini-2024-07-18.json') as f:
    nv_task_gpt_json = json.load(f)

# Convert to dictionary and clean
nv_task_gpt = {}
for item in nv_task_gpt_json:
    pmcid = item['pmcid']
    nv_task_gpt[pmcid] = {}
    for key, value in item.items():
        value = None if value in ['null', []] else value
        if key == 'Designtype':
            key = 'DesignType'

        if key == 'Modality':
            value = [v.replace(' ', '') for v in value]

        nv_task_gpt[pmcid][key] = value

# %% [markdown]
# #### Load Annotations

# %%
from labelrepo.projects.nv_task import load_annotations

annotations = load_annotations()
annotations = annotations[annotations['annotator_name'] != 'alice_chen']
# Out:
# Inserting documents from /home/zorro/repos/labelbuddy-annotations/documents
# Inserting labels from /home/zorro/repos/labelbuddy-annotations/projects/NER_biomedical/labels
# Inserting annotations from /home/zorro/repos/labelbuddy-annotations/projects/NER_biomedical/annotations
# Inserting labels from /home/zorro/repos/labelbuddy-annotations/projects/autism_mri/labels
# Inserting annotations from /home/zorro/repos/labelbuddy-annotations/projects/autism_mri/annotations
# Inserting labels from /home/zorro/repos/labelbuddy-annotations/projects/cluster_inference/labels
# Inserting annotations from /home/zorro/repos/labelbuddy-annotations/projects/cluster_inference/annotations
# Inserting labels from /home/zorro/repos/labelbuddy-annotations/projects/cobidas/labels
# Inserting annotations from /home/zorro/repos/labelbuddy-annotations/projects/cobidas/annotations
# Inserting labels from /home/zorro/repos/labelbuddy-annotations/projects/dynamic_functional_connectivity/labels
# Inserting annotations from /home/zorro/repos/labelbuddy-annotations/projects/dynamic_functional_connectivity/annotations
# Inserting labels from /home/zorro/repos/labelbuddy-annotations/projects/neuro-meta-analyses/labels
# Inserting annotations from /home/zorro/repos/labelbuddy-annotations/projects/neuro-meta-analyses/annotations
# Inserting labels from /home/zorro/repos/labelbuddy-annotations/projects/neuro-meta-analysis-tables/labels
# Inserting annotations from /home/zorro/repos/labelbuddy-annotations/projects/neuro-meta-analysis-tables/annotations
# Inserting labels from /home/zorro/repos/labelbuddy-annotations/projects/neuro-meta-analysis_manually-inspected-topics/labels
# Inserting annotations from /home/zorro/repos/labelbuddy-annotations/projects/neuro-meta-analysis_manually-inspected-topics/annotations
# Inserting labels from /home/zorro/repos/labelbuddy-annotations/projects/neurobridge_fmri/labels
# Inserting annotations from /home/zorro/repos/labelbuddy-annotations/projects/neurobridge_fmri/annotations
# Inserting labels from /home/zorro/repos/labelbuddy-annotations/projects/neurosynth_use/labels
# Inserting annotations from /home/zorro/repos/labelbuddy-annotations/projects/neurosynth_use/annotations
# Inserting labels from /home/zorro/repos/labelbuddy-annotations/projects/nv_task/labels
# Inserting annotations from /home/zorro/repos/labelbuddy-annotations/projects/nv_task/annotations
# Inserting labels from /home/zorro/repos/labelbuddy-annotations/projects/old_review-neuro-meta-analyses/labels
# Inserting annotations from /home/zorro/repos/labelbuddy-annotations/projects/old_review-neuro-meta-analyses/annotations
# Inserting labels from /home/zorro/repos/labelbuddy-annotations/projects/parkinsons/labels
# Inserting annotations from /home/zorro/repos/labelbuddy-annotations/projects/parkinsons/annotations
# Skipped 35 annotations in parkinsons due to missing documents
# Inserting labels from /home/zorro/repos/labelbuddy-annotations/projects/participant_demographics/labels
# Inserting annotations from /home/zorro/repos/labelbuddy-annotations/projects/participant_demographics/annotations
# Inserting labels from /home/zorro/repos/labelbuddy-annotations/projects/tracking_open_datasets/labels
# Inserting annotations from /home/zorro/repos/labelbuddy-annotations/projects/tracking_open_datasets/annotations
# Database created in /home/zorro/repos/labelbuddy-annotations/analysis/data/database.sqlite3

# %%
def _get_task_name(rows):
    # Add TaskName, replacing 'None' and 'Unsure' with 'n/a'
    rows = rows[rows.label_name == 'TaskName']
    task_names = []
    for _, row in rows.iterrows():
        if row['None'] or row['Unsure']:
            task_names.append('n/a')
        else:
            task_names.append(row['selected_text'])
    return task_names

# Convert to comparable dictionary
annotations_summary = {}
for pmcid, df in annotations.groupby('pmcid'):
    design_type = []
    if 'DesignType-RestingState' in df.label_name.values:
        design_type.append('RestingState')
    if 'TaskName' in df.label_name.values:
        design_type.append('Task-based')

    s = {
        'pmcid': pmcid,
        'DesignType': design_type,
        'annotator_name': df.annotator_name.iloc[0],
        'Exclude': next(
            (label.split('-', 1)[1] for label in df.label_name if label.startswith('Exclude')), None
        ),
        'Modality': [
            label.split('-', 1)[1] for label in df.label_name if label.startswith('Modality')
        ] or None,
    }

    df_abstract = df[df.section == 'abstract']
    abstract_tasks = _get_task_name(df_abstract)

    df_body = df[df.section == 'body']
    body_tasks = _get_task_name(df_body)

    # Use body tasks if available, otherwise use abstract tasks
    s['TaskName'] = body_tasks or abstract_tasks

    for k in ['TaskDescription', 'Condition', 'ContrastDefinition']:
        s[k] = df_body.loc[df_body.label_name == k, 'selected_text'].tolist() or None

    annotations_summary[pmcid] = s

# %% [markdown]
# ### Compare Extractions to Annotations

# %%
import re
from thefuzz import process, fuzz

def _clean(x):
    _li =  [x.lower().replace('paradigm', '').replace('task', '').replace('‐', '').strip() for x in (x or [])]

    # Remove abbreviations
    return [re.sub(r'\s*\([^)]*\)', '', x) for x in _li]

def _compare(x, y):
    x = x or ''
    y = y or ''
    return x.replace('-', '').lower() == y.replace('-', '').lower()

def score_fuzzy(correct_labels, extracted_labels):
    correct_labels = _clean(correct_labels)
    extracted_labels = _clean(extracted_labels)
    
    matched_labels = []
    
    while correct_labels and extracted_labels:
        # Collect all matches and their scores
        all_matches = []
        for correct_label in correct_labels:
            matches = process.extract(correct_label, extracted_labels, limit=None, scorer=fuzz.token_set_ratio
            for matched_label, score in matches:
                all_matches.append((correct_label, matched_label, score))

        # Sort all matches by score in descending order
        all_matches.sort(key=lambda x: x[2], reverse=True)

        # Take the highest match
        best_match = all_matches[0]
        correct_label, matched_label, score = best_match

        # Append to results and remove matched labels
        matched_labels.append(score)
        correct_labels.remove(correct_label)
        extracted_labels.remove(matched_label)

    matched_labels = (sum(matched_labels) / len(matched_labels)) / 100 if matched_labels else 0

    return matched_labels


def _compare(x, y):
    x = x or ''
    y = y or ''
    return x.replace('-', '').lower() == y.replace('-', '').lower()

# %%
# Compare annotations to extractions
all_scores = {}


for pmcid, ann in annotations_summary.items():
    all_scores[pmcid] = {
        'Exclude': _compare(ann['Exclude'], nv_task_gpt[pmcid]['Exclude'])
    }

    # N items match
    for k in ['TaskName', 'Condition', 'ContrastDefinition', 'DesignType', 'Modality']:
        all_scores[pmcid][k] = score_fuzzy(ann[k], nv_task_gpt[pmcid][k])

# Calculate scores
n_articles = len(annotations_summary.keys())

all_scores_df = pd.DataFrame(all_scores).T
# Out:
# WARNING:thefuzz.process:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ',']
# WARNING:thefuzz.process:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ',']
# WARNING:thefuzz.process:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ',']
# WARNING:thefuzz.process:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:thefuzz.process:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:thefuzz.process:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:thefuzz.process:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ',']
# WARNING:thefuzz.process:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: ',']
# WARNING:thefuzz.process:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:thefuzz.process:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:thefuzz.process:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']

# %%
# Overall scores
all_scores_df.mean()
# Out:
# Exclude               0.980769
# TaskName              0.601971
# Condition             0.542547
# ContrastDefinition    0.412943
# DesignType            0.867692
# Modality              0.913462
# dtype: object

# %%
# Excluding articles with 'Exclude' label
exclude_idx = [_p for _p, v in annotations_summary.items() if v['Exclude'] is not None]
all_scores_df.loc[~all_scores_df.index.isin(exclude_idx)].mean()
# Out:
# Exclude                    1.0
# TaskName                 0.659
# Condition             0.593946
# ContrastDefinition    0.452064
# DesignType            0.949895
# Modality                   1.0
# dtype: object

# %%
# For papers with a clearly defined task name
has_task_name = [_p for _p, v in annotations_summary.items() if 'Task-based' in v['DesignType'] and 'n/a' not in v['TaskName']]
all_scores_df.loc[all_scores_df.index.isin(has_task_name)].mean()
# Out:
# Exclude                    1.0
# TaskName              0.925078
# Condition             0.719061
# ContrastDefinition    0.571641
# DesignType                 1.0
# Modality                   1.0
# dtype: object

# %%
# For papers with a task-based design but no annotated task name
has_task_noname = [_p for _p, v in annotations_summary.items() if 'Task-based' in v['DesignType'] and 'n/a' in v['TaskName']]
all_scores_df.loc[all_scores_df.index.isin(has_task_noname)].mean()
# Out:
# Exclude                    1.0
# TaskName              0.188889
# Condition             0.578056
# ContrastDefinition    0.353395
# DesignType                 1.0
# Modality                   1.0
# dtype: object

# %% [markdown]
# ### Manual comparison

# %%
combined_df = pd.concat([pd.DataFrame(annotations_summary).T, pd.DataFrame(nv_task_gpt).T])

# %%
import pandas as pd
from IPython.display import display

pd.set_option('max_colwidth', 300)
    

def _display(df, pmcids=None):
    cols = list(set(df.keys()) - set(['pmcid']))
    if pmcids:
        df = df[df.pmcid.isin(pmcids)]
    for _, _df in df.groupby('pmcid'):
        display(_df[cols])

# %%
# Diff on Exclude

diff_exclude = all_scores_df[all_scores_df['Exclude'] == False].index.tolist()

if diff_exclude:
    _display(combined_df, diff_exclude)
# Out:
#                                    Condition       Exclude annotator_name  \
# 3555187                                 None  MetaAnalysis    delavega_nv
# 3555187  [sensorimotor tasks, SRTT variants]          None            NaN
#
#                                                                                                                                                                                       ContrastDefinition  \
# 3555187                                                                                                                                                                                             None
# 3555187  [activity in the basal ganglia and cerebellum was significantly stronger for sensorimotor tasks, activity in cortical structures and the thalamus was significantly stronger for SRTT variants]
#
#                                                                                                                                                                                                                                                                               TaskDescription  \
# 3555187                                                                                                                                                                                                                                                                                  None
# 3555187  [The study identified consistent activations across 70 motor learning experiments using activation likelihood estimation (ALE) meta-analysis. A global analysis of all tasks revealed a bilateral cortical-subcortical network consistently underlying motor learning across tasks.]
#
#             Modality                                     TaskName  \
# 3555187         None                                           []
# 3555187  [fMRI-BOLD]  [motor learning, serial response time task]
#
#            DesignType
# 3555187            []
# 3555187  [Task-based]
#                             Condition       Exclude         annotator_name  \
# 10634720                         None  MetaAnalysis  delavega-aliceoverlap
# 10634720  [Exploration, Exploitation]          None                    NaN
#
#                                                 ContrastDefinition  \
# 10634720                                                      None
# 10634720  [exploration > exploitation, exploitation > exploration]
#
#                                                                                                                                                                                                TaskDescription  \
# 10634720                                                                                                                                                                                                  None
# 10634720  [Participants engage in tasks that require them to make decisions about whether to explore new options or exploit known ones, using various task designs such as n-armed bandit and foraging tasks.]
#
#              Modality                           TaskName    DesignType
# 10634720         None                                 []            []
# 10634720  [fMRI-BOLD]  [Explore-Exploit Decision Making]  [Task-based]

# %%
# From now on, we will exclude Excluded articles
combined_df = combined_df[~combined_df.index.isin(exclude_idx)]

# %%
# Diff on DesignType

diff_dt = all_scores_df[all_scores_df['DesignType'] < 1].index.tolist()

if diff_dt:
    _display(combined_df, diff_dt)
# Out:
#                                                                                Condition  \
# 6331309                                                                             None
# 6331309  [Migraine, Restless Legs Syndrome, Comorbid Migraine and RLS, Healthy Controls]
#
#         Exclude annotator_name  \
# 6331309    None    delavega_nv
# 6331309    None            NaN
#
#                                                                                                               ContrastDefinition  \
# 6331309                                                                                                                     None
# 6331309  [Migraine vs Healthy Controls, RLS vs Healthy Controls, Migraine vs RLS, Comorbid Migraine and RLS vs Healthy Controls]
#
#                                                                                                                                                                            TaskDescription  \
# 6331309                                                                                                                                                                               None
# 6331309  [High-resolution T1-weighted images were acquired from 116 subjects: 27 RLS patients, 22 migraine patients, 22 patients with comorbid migraine and RLS, and 45 healthy controls.]
#
#                 Modality                TaskName    DesignType
# 6331309  [StructuralMRI]                      []            []
# 6331309  [StructuralMRI]  [MRI data acquisition]  [Task-based]
#                                          Condition Exclude  \
# 7426775                                       None    None
# 7426775  [Age prediction based on structural MRI.]    None
#
#                 annotator_name  \
# 7426775  delavega-aliceoverlap
# 7426775                    NaN
#
#                                      ContrastDefinition  \
# 7426775                                            None
# 7426775  [Age-related structural changes in the brain.]
#
#                                                                                TaskDescription  \
# 7426775                                                                                   None
# 7426775  [Predicting chronological age from structural MRI scans using a deep learning model.]
#
#                 Modality                TaskName    DesignType
# 7426775  [StructuralMRI]                      []            []
# 7426775  [StructuralMRI]  [Brain Age Prediction]  [Task-based]
#                                                     Condition Exclude  \
# 7582181                                                  None    None
# 7582181  [Social reward expectancy, Social threat expectancy]    None
#
#                 annotator_name  \
# 7582181  delavega-aliceoverlap
# 7582181                    NaN
#
#                                               ContrastDefinition  \
# 7582181                                                     None
# 7582181  [Social reward expectancy vs. social threat expectancy]
#
#                                                                                                                                                             TaskDescription  \
# 7582181                                                                                                                                                                None
# 7582181  [Participants were asked to vividly imagine themselves in a novel self-relevant event that was ambiguous with regards to possible social acceptance or rejection.]
#
#                 Modality                         TaskName    DesignType
# 7582181  [StructuralMRI]                               []            []
# 7582181  [StructuralMRI]  [Imagining social interactions]  [Task-based]
#                                          Condition Exclude  \
# 8564184                                       None    None
# 8564184  [Chronic visceral pain, Healthy controls]    None
#
#                 annotator_name  \
# 8564184  delavega-aliceoverlap
# 8564184                    NaN
#
#                                                                                                                                                                                          ContrastDefinition  \
# 8564184                                                                                                                                                                                                None
# 8564184  [GMV in ulcerative colitis vs. healthy controls, GMV in irritable bowel syndrome vs. healthy controls, Correlations between GMV and symptom severity, Correlations between GMV and chronic stress]
#
#                                                                                                                                                                                                TaskDescription  \
# 8564184                                                                                                                                                                                                   None
# 8564184  [Parallelized whole-brain voxel-based morphometry analyses in two patient cohorts with chronic visceral pain (ulcerative colitis in remission and irritable bowel syndrome) and healthy individuals.]
#
#                 Modality                   TaskName    DesignType
# 8564184  [StructuralMRI]                         []            []
# 8564184  [StructuralMRI]  [Voxel-based morphometry]  [Task-based]
#                                           Condition Exclude  \
# 9202476                                        None    None
# 9202476  [poor sleepers (PSs), good sleepers (GSs)]    None
#
#                 annotator_name  ContrastDefinition  \
# 9202476  delavega-aliceoverlap                None
# 9202476                    NaN  [PS > GS, GS > PS]
#
#                                                                                                                                                                                                                                                                                                      TaskDescription  \
# 9202476                                                                                                                                                                                                                                                                                                         None
# 9202476  [In this computerized task, subjects were presented with a complex figure in the middle of the screen. Then, a few patterns were shown in the periphery, from which one was matched with the presented pattern. In the first trials, two patterns were presented in the periphery, and it was increased ...
#
#                           Modality                      TaskName  \
# 9202476  [fMRI-BOLD, DiffusionMRI]                            []
# 9202476  [fMRI-BOLD, DiffusionMRI]  [match-to-sample (MTS) task]
#
#              DesignType
# 9202476  [RestingState]
# 9202476    [Task-based]

# %%
all_scores_df.loc[2686646]
# Out:
# Exclude                   True
# TaskName                   0.8
# Condition             0.913333
# ContrastDefinition         1.0
# DesignType                 1.0
# Modality                   1.0
# Name: 2686646, dtype: object

# %% [markdown]
# It seems most misses by GPT were due to task performed *outside the scanner*, yet listed as Task-based design, which in this instance should only refer to Task-based fMRI design

# %%
# Diff on TaskName

has_taskname_df = combined_df[combined_df.index.isin(has_task_name)]

diff_taskname = all_scores_df[all_scores_df['TaskName'] < 0.8].index.tolist()

if diff_taskname:
    _display(has_taskname_df, diff_taskname)
# Out:
#                                                      Condition Exclude  \
# 4374765  [spiders, control animals, IAPSnegative, IAPSneutral]    None
# 4374765          [SPIDERS, ANIMALS, IAPSnegative, IAPSneutral]    None
#
#         annotator_name                               ContrastDefinition  \
# 4374765    delavega_nv  [SPIDERS > ANIMALS, IAPSnegative > IAPSneutral]
# 4374765            NaN  [SPIDERS > ANIMALS, IAPSnegative > IAPSneutral]
#
#                                                                                                                                                                                                                                                                                                      TaskDescription  \
# 4374765                                                                                                                                                                                                                                                                                                         None
# 4374765  [Participants were presented with still pictures of spiders, control animals (birds, caterpillars, snails, and lizards), negative pictures from the International Affective Picture System (IAPS), and neutral pictures from IAPS. They performed a covert task of detecting the presence of a human in ...
#
#                  Modality                     TaskName    DesignType
# 4374765  [MRS, fMRI-BOLD]     [fear inducing paradigm]  [Task-based]
# 4374765  [fMRI-BOLD, MRS]  [Fear provocation paradigm]  [Task-based]
#                       Condition Exclude         annotator_name  \
# 5324609                    None    None  delavega-aliceoverlap
# 5324609  [rewarded, unrewarded]    None                    NaN
#
#                                                                                                                                                                                          ContrastDefinition  \
# 5324609  [linear increases in activity across the four learning stage,  HRF amplitude estimates relating to generalization test trials were correlated with generalization performance at the second‐level]
# 5324609                                                                                [generalization performance, hippocampal activity during the test, BOLD activity during the final stage of learning]
#
#                                                                                                                                                                                                                                                                                                      TaskDescription  \
# 5324609  [participants learned a set of visual discriminations via trial‐and‐error (learning phase), and were subsequently tested on their ability to generalize what they had learned (generalization phase). Both learning and generalization occurred within a single scanning session and took place in the c...
# 5324609  [During scanning participants learned a set of visual discriminations via trial-and-error (learning phase), and were subsequently tested on their ability to generalize what they had learned (generalization phase). Both learning and generalization occurred within a single scanning session and too...
#
#                        Modality                                TaskName  \
# 5324609  [fMRI-BOLD, fMRI-BOLD]             [acquired equivalence task]
# 5324609             [fMRI-BOLD]  [learning phase, generalization phase]
#
#            DesignType
# 5324609  [Task-based]
# 5324609  [Task-based]
#                                           Condition Exclude  annotator_name  \
# 5776089  [Task, Task+AgonistStim, Task+ControlStim]    None  delavega-other
# 5776089  [Task, Task+AgonistStim, Task+ControlStim]    None             NaN
#
#                                                                                     ContrastDefinition  \
# 5776089                                                                [“Task+AgonistStim minus Task”]
# 5776089  [Task+AgonistStim vs. Task, Task+ControlStim vs. Task, Task+AgonistStim vs. Task+ControlStim]
#
#                                                                                                                                                                                                                                                                                                      TaskDescription  \
# 5776089  [he fMRI session was composed of nine rest–task cycles with 30 s for each period. Eyes were kept closed during scanning. The motor task consisted of repetitive alternating dorsiflexion and relaxation of the right foot (with range reaching 15°). Foot movements were paced following an audio cue th...
# 5776089                                                                                                  [The motor task consisted of repetitive alternating dorsiflexion and relaxation of the right foot (with range reaching 15). Foot movements were paced following an audio cue that was sounded every 1.5 s.]
#
#             Modality  \
# 5776089  [fMRI-BOLD]
# 5776089  [fMRI-BOLD]
#
#                                                                                                                                                                                        TaskName  \
# 5776089                                                                                                                                                 [Motor Task, Somatosensory Stimulation]
# 5776089  [right ankle dorsiflexion, ankle dorsiflexion coupled with simultaneous stimulation to the agonist muscle, ankle dorsiflexion coupled with simultaneous stimulation to a control area]
#
#            DesignType
# 5776089  [Task-based]
# 5776089  [Task-based]
#                                                        Condition Exclude  \
# 6219793                          [self-distanced, self-immersed]    None
# 6219793  [Self-distanced perspective, Self-immersed perspective]    None
#
#         annotator_name  \
# 6219793    delavega_nv
# 6219793            NaN
#
#                                                        ContrastDefinition  \
# 6219793                                                              None
# 6219793  [Self-distanced > Self-immersed, Self-immersed > Self-distanced]
#
#                                                                                                                                                                                                                                                                                                      TaskDescription  \
# 6219793  [Following previous studies [ – ], negative social feedback was used to induce emotions for two reasons: (a) in daily life emotions are often caused by social stimuli [ , ] and (b) social feedback elicits emotional responses that are long enough to study emotion dynamics [ ]. The social feedback...
# 6219793                                                                                                                                                                  [Participants were asked to adopt a self-immersed or self-distanced perspective while reading and thinking about negative social feedback.]
#
#             Modality                                        TaskName  \
# 6219793  [fMRI-BOLD]                      [Social feedback paradigm]
# 6219793  [fMRI-BOLD]  [Self-distanced vs. self-immersed perspective]
#
#            DesignType
# 6219793  [Task-based]
# 6219793  [Task-based]
#                                        Condition Exclude annotator_name  \
# 6699247                                     None    None    delavega_nv
# 6699247  [matched, in-category, out of category]    None            NaN
#
#                        ContrastDefinition  \
# 6699247                              None
# 6699247  [IC vs. matched, OC vs. matched]
#
#                                                                                                                                                                                                                                                                                                      TaskDescription  \
# 6699247  [In this task, a simple line drawing of an object is presented (250 ms), and following a short delay (75 ms), a word appears. Subjects are instructed to respond by indicating whether the word was a semantic match (50% of trials) or non-match (unmatched, 50% of trials) to the preceding picture. P...
# 6699247                                                                                                                            [Participants performed a picture-word matching task, in which words were either matched by preceding pictures, or were unmatched by semantically related or unrelated pictures.]
#
#                       Modality                          TaskName    DesignType
# 6699247  [EEG, fMRI-BOLD, MRS]  [picture–word verification task]  [Task-based]
# 6699247            [fMRI-BOLD]      [picture-word matching task]  [Task-based]
#                                                                                                                                   Condition  \
# 7018765  [“both correct”, “costly error”, participant responded incorrectly, both the participant and their partner responded incorrectly,]
# 7018765                                                                                    [costly error condition, both correct condition]
#
#         Exclude         annotator_name  \
# 7018765    None  delavega-aliceoverlap
# 7018765    None                    NaN
#
#                                                         ContrastDefinition  \
# 7018765  [“costly error” – “both correct”, “costly error”, “both correct”]
# 7018765                                    [costly error vs. both correct]
#
#                                                                                                                                                                                                                                                                                                      TaskDescription  \
# 7018765  [his task builds on past studies that have utilized error processing paradigms in the study of ER (e.g.,  ;  ;  ) by specifically examining dyadic error processing. Parent-adolescent dyads completed the TEAM task while simultaneously undergoing fMRI scanning. This task was developed to examine b...
# 7018765  [The TEAM task is an event-related design and consists of 17 trials during which participants first see a pattern of colored arrows presented sequentially on the screen for 3 s, twice in a row (totaling 6 s). They are then given 4 s to reconstruct the sequence by pressing colored buttons on a re...
#
#             Modality                                             TaskName  \
# 7018765  [fMRI-BOLD]  [Testing Emotional Attunement and Mutuality (TEAM)]
# 7018765  [fMRI-BOLD]                                          [TEAM task]
#
#            DesignType
# 7018765  [Task-based]
# 7018765  [Task-based]
#                                                                                    Condition  \
# 11063816  [open-loop, delay, open-loop, no-delay, closed-loop, delay, closed-loop, no-delay]
# 11063816                                                                   [Delay, No-delay]
#
#          Exclude  annotator_name  \
# 11063816    None  delavega-other
# 11063816    None             NaN
#
#                                                                                                                                                                                                                                                                                                    ContrastDefinition  \
# 11063816  [people, locations, objects, nontarget reinstatement effect, collapsing across the delay and no-delay condition, nontarget reinstatement effect differed between the delay and no-delay conditions , differences between closed- and open-loops in the cue and target regions in the delay and no-delay ...
# 11063816                                                                                                                                                                                                                                                   [closed-loop vs open-loop, immediate vs delayed retrieval]
#
#                                                                                                                                                                                                                                                                                                       TaskDescription  \
# 11063816  [On each trial, a cue and six potential targets were presented simultaneously on the screen. The cue was presented in the middle of the screen with the six possible targets; one target and five foils form the same category (e.g., if the target was hammer, the five foils would be other randomly s...
# 11063816  [Participants learned events that comprised multiple overlapping pairs of event elements (e.g., person-location, object-location, location-person). Encoding occurred either immediately before or 24h before retrieval. Using fMRI during the retrieval of events, the study assessed whether episodic ...
#
#                         Modality  \
# 11063816  [fMRI-BOLD, fMRI-BOLD]
# 11063816             [fMRI-BOLD]
#
#                                                        TaskName    DesignType
# 11063816  [six-alternative forced-choice cued-recognition task]  [Task-based]
# 11063816                            [Episodic memory retrieval]  [Task-based]

# %%
all_scores_df.shape
# Out:
# (104, 6)

# %% [markdown]
# Many misses are due to "Resting-state" being listed as a task for Resting-State paradigms, whereas they were coded as None by annotators.
# Sometimes it will also list a task-name that is outside the scanner.
#
# The vast majority of the remaining tasks could be classified as "correct".
#
# Using fuzzy matching, only 7 / 96 studies had poor matching, in 3-4 of these, it could be argued to be semantically correct.
# Only in 1-2 of these cases would I outright call it incorrect.
