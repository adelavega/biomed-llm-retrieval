# %% [markdown]
# ## Full text semantic search - demo
#
# In order to perform IR over full texts, we need to find relevant section to use as context for GPT.
#
# This is typically done by chunking texts into sections, and obtaining embeddings for each section of the text.
# Then, using a distance metric, one can find the most relevant section for use as context to the GPT query.
#
# Here, I will evaluate this method for finding sample size in papers that do not list it in the Abstract.

# %% [markdown]
# ### Setup
# Load participant annotations, and full text for documents

# %%
import pandas as pd
from labelrepo.projects.participant_demographics import (
    get_participant_demographics, select_participants_annotations
)

subgroups = get_participant_demographics(include_locations=True)

# %%
from labelrepo.database import get_database_connection

import pandas as pd

docs_info = pd.read_sql(
    "select pmcid, publication_year, title, text from document",
    get_database_connection(),
)

# %%
subgroups = pd.merge(subgroups, docs_info, how='left')
jerome_pd = subgroups[(subgroups.project_name == 'participant_demographics') & \
                      (subgroups.annotator_name == 'Jerome_Dockes')]

counts = jerome_pd.groupby('pmcid').count().reset_index()
single_group_pmcids = counts[counts['count'] == 1].pmcid
single_group = jerome_pd[jerome_pd.pmcid.isin(single_group_pmcids)]

# %% [markdown]
# # Case study
#
# Testing out workflow with single study with participant info not in Abstact

# %%
example = single_group[single_group.pmcid == 5548834]

# %%
full_text = example.text.values[0]

# %% [markdown]
# ### Chunk Full Text
#
# The maximum context length is 4k-16k tokens for GPT 3.5, therefore we need to break up the text into chunks/
# The following chunks PMC articles by Markdown into sections

# %%
import openai
import numpy as np
from embed import embed_pmc_article, embed_text
openai.api_key = open('/home/zorro/.keys/open_ai.key').read().strip()

# %% [markdown]
# ### Embed chunks
#
# `embed_pmc_article` chunks the document, and retrieves embeddings for each chunk, returned alongside chunk meta-data

# %%
embeddings = embed_pmc_article(full_text, model_name='text-embedding-ada-002')

# %%
embeddings = pd.DataFrame(embeddings)

# %% [markdown]
# ### Test Query

# %%
query = "How many subjects are in the study?"

query_embedding = embed_text(query)

# %%
from sklearn.metrics.pairwise import euclidean_distances

# %%
doc_embeddings = np.array(embeddings['embedding'].tolist())
distances = euclidean_distances(doc_embeddings, np.array(query_embedding).reshape(1, -1), squared=True)
embeddings['distances'] = distances
embeddings.sort_values('distances')
# Out:
#    section_name                                            content  \
# 6          Body  \n## Method \n  \n### Participants \n  \nParti...
# 0       Authors  Riem, Madelon M. E. and Van Ijzendoorn, Marinu...
# 11         Body  \n### fMRI paradigm and data acquisition \n  \...
# 10         Body  \n### Stimuli \n  \nAll infant faces images an...
# 7          Body  \n### Procedure \n  \nParticipants were invite...
# 8          Body  \nThe second part of the BSRT consisted of the...
# 12         Body  \n### fMRI data acquisition and analysis \n  \...
# 13         Body  \nAll first-level contrast images and the corr...
# 9          Body  \nAfter the training phase participants were r...
# 14         Body  \n## Results \n  \n### Behavioral analyses \n ...
# 1         Title  \n# Title\n\nExperimental manipulation of infa...
# 16         Body  \nIn additional analyses, we assessed the cont...
# 3      Abstract  \n# Abstract\n \nIn this functional magnetic r...
# 20         Body  \nOur study has a few limitations. First, func...
# 2      Keywords  \n# Keywords\n\nAmygdala\nfMRI\nFunctional con...
# 18         Body  \n## Discussion \n  \nThe current fMRI study i...
# 15         Body  \n### Functional brain activation \n  \nA whol...
# 4          Body  \n# Body\n \n## Introduction \n  \nWhile all i...
# 5          Body  \nIn addition to amygdala activity,   connecti...
# 17         Body  \n### Functional connectivity \n  \nWe perform...
# 19         Body  \nContrary to our expectations, we did not fin...
#
#     start_char  end_char                                          embedding  \
# 6         7835      9127  [-0.01049839984625578, 0.013235046528279781, 0...
# 0            0       218  [-0.018246043473482132, -0.0213411133736372, 0...
# 11       16747     18029  [-0.03294625133275986, 0.015457101166248322, 0...
# 10       15342     16747  [-0.05092040076851845, 0.008138147182762623, 0...
# 7         9127     11203  [-0.03600265458226204, 0.006860304158180952, 0...
# 8        11203     14248  [-0.027335399761795998, 0.009072703309357166, ...
# 12       18029     21410  [-0.021956197917461395, 0.02941172942519188, 0...
# 13       21410     23525  [-0.019373657181859016, 0.021196560934185982, ...
# 9        14248     15342  [-0.02984154224395752, 0.010838804766535759, 0...
# 14       23525     24503  [-0.018938401713967323, 0.024022815749049187, ...
# 1          218       317  [-0.03099415823817253, 0.019643226638436317, 0...
# 16       27875     28613  [-0.013316984288394451, 0.022808529436588287, ...
# 3          395      1757  [-0.031790733337402344, 0.01572083868086338, 0...
# 20       38546     42207  [-0.03365343064069748, 0.008530300110578537, 0...
# 2          317       395  [-0.02879667468369007, 0.022748302668333054, 0...
# 18       31934     34873  [-0.03658870980143547, 0.014063281938433647, 0...
# 15       24503     27875  [-0.01962992176413536, 0.01048003975301981, 0....
# 4         1757      4226  [-0.021865395829081535, 0.0037463766057044268,...
# 5         4226      7835  [-0.042132314294576645, 0.008235550485551357, ...
# 17       28613     31934  [-0.006800406612455845, 0.02650069259107113, 0...
# 19       34873     38546  [-0.03665860742330551, 0.0037294230423867702, ...
#
#     distances
# 6    0.392560
# 0    0.440493
# 11   0.452415
# 10   0.454937
# 7    0.469708
# 8    0.475538
# 12   0.476900
# 13   0.483069
# 9    0.486831
# 14   0.489271
# 1    0.514416
# 16   0.517289
# 3    0.522458
# 20   0.525177
# 2    0.525836
# 18   0.528354
# 15   0.536175
# 4    0.553341
# 5    0.565832
# 17   0.567854
# 19   0.572418

# %% [markdown]
# The closest passage is where the participant information is found!

# %% [markdown]
# ### Comparison to Jerome's annotations
#
# The goal here is to see if across documents we can design a query that will find the target passage (i.e. where the participant informaton actually exists)

# %%
top_1 = embeddings.sort_values('distances').iloc[0]
example.start_char > top_1.start_char

# %%
example.end_char < top_1.end_char
